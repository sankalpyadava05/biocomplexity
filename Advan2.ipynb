# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus
import os
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point
import seaborn as sns
import folium
from folium.plugins import HeatMap
import glob
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Line3DCollection
from sklearn.metrics import pairwise_distances
from scipy.linalg import sqrtm
from scipy.special import digamma, loggamma
from math import pi

# %%
folder = os.path.expanduser("~/Desktop/Biocomplexity Institute/09_24")

# %%
week = "2024-09-02"
files = sorted(glob.glob(os.path.join(folder, f"Weekly_Patterns_Foot_Traffic_Full_Historical_Data-*-DATE_RANGE_START-{week}.csv")))
print(f"{len(files)} files found for {week}")

dfs = [pd.read_csv(f) for f in files]
week_df = pd.concat(dfs, ignore_index=True)
week_df["week_start"] = week
week_df.to_csv(os.path.join(folder, f"advan_week_{week}.csv"), index=False)

for f in files:
    os.remove(f)
print(f"combined and cleaned up {week}")
# Out:
# 500 files found for 2024-09-02
# combined and cleaned up 2024-09-02

# %%
week = "2024-09-09"
files = sorted(glob.glob(os.path.join(folder, f"Weekly_Patterns_Foot_Traffic_Full_Historical_Data-*-DATE_RANGE_START-{week}.csv")))
print(f"{len(files)} files found for {week}")

dfs = [pd.read_csv(f) for f in files]
week_df = pd.concat(dfs, ignore_index=True)
week_df["week_start"] = week
week_df.to_csv(os.path.join(folder, f"advan_week_{week}.csv"), index=False)

for f in files:
    os.remove(f)
print(f"combined and cleaned up {week}")
# Out:
# 500 files found for 2024-09-09
# combined and cleaned up 2024-09-09

# %%
week = "2024-09-16"
files = sorted(glob.glob(os.path.join(folder, f"Weekly_Patterns_Foot_Traffic_Full_Historical_Data-*-DATE_RANGE_START-{week}.csv")))
print(f"{len(files)} files found for {week}")

dfs = [pd.read_csv(f) for f in files]
week_df = pd.concat(dfs, ignore_index=True)
week_df["week_start"] = week
week_df.to_csv(os.path.join(folder, f"advan_week_{week}.csv"), index=False)

for f in files:
    os.remove(f)
print(f"combined and cleaned up {week}")

# %%
week = "2024-09-23"
files = sorted(glob.glob(os.path.join(folder, f"Weekly_Patterns_Foot_Traffic_Full_Historical_Data-*-DATE_RANGE_START-{week}.csv")))
print(f"{len(files)} files found for {week}")

dfs = [pd.read_csv(f) for f in files]
week_df = pd.concat(dfs, ignore_index=True)
week_df["week_start"] = week
week_df.to_csv(os.path.join(folder, f"advan_week_{week}.csv"), index=False)

for f in files:
    os.remove(f)
print(f"combined and cleaned up {week}")

# %%
week = "2024-09-30"
files = sorted(glob.glob(os.path.join(folder, f"Weekly_Patterns_Foot_Traffic_Full_Historical_Data-*-DATE_RANGE_START-{week}.csv")))
print(f"{len(files)} files found for {week}")

dfs = [pd.read_csv(f) for f in files]
week_df = pd.concat(dfs, ignore_index=True)
week_df["week_start"] = week
week_df.to_csv(os.path.join(folder, f"advan_week_{week}.csv"), index=False)

for f in files:
    os.remove(f)
print(f"combined and cleaned up {week}")
